# %% [markdown]
# Synset based topic modeling

# %%
#install libraries
pip install nltk scikit-learn gensim
pip install PyPDF2
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Collecting numpy>=1.19.5 (from scikit-learn)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.7 MB/s eta 0:00:00
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Downloading gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 23.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 83.2 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 13.1 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %% [markdown]
# Syntopextract-Context based topic extraction for agricultural documents

# %%
#import libraries
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.wsd import lesk

from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary

import PyPDF2

# %%
# ==== NLTK Download (run once) ====
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')  # For enhanced WordNet
nltk.download('punkt_tab') # Download the missing resource
nltk.download('averaged_perceptron_tagger_eng') # Download the missing resource

# %%
#synset based topic modeling
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def read_pdf(file_path):
    text = ""
    with open(file_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            page_text = page.extract_text()
            if page_text:
                text += page_text + " "
    return text

def preprocess_document(text):
    sentences = sent_tokenize(text)
    sentence_data = []
    for sent in sentences:
        tokens = word_tokenize(sent)
        filtered_tokens = [t for t in tokens if t.isalpha() and t.lower() not in stop_words]
        tagged_tokens = nltk.pos_tag(filtered_tokens)
        lemmas = [lemmatizer.lemmatize(token.lower(), pos=get_wordnet_pos(pos_tag))
                  for token, pos_tag in tagged_tokens]
        sentence_data.append({
            'original_sentence': sent,
            'lemmas': lemmas,
            'tokens': filtered_tokens
        })
    return sentence_data

def assign_synsets_to_lemmas(doc_sentence_data):
    synset_map = {}
    for entry in doc_sentence_data:
        sent_tokens = word_tokenize(entry['original_sentence'])
        for lemma in entry['lemmas']:
            if lemma not in synset_map:
                syn = lesk(sent_tokens, lemma)
                if syn is None:
                    synsets = wordnet.synsets(lemma)
                    # Assign None if no synset is found
                    syn = synsets[0] if synsets else None
                synset_map[lemma] = syn
    return synset_map

def group_lemmas_by_synset(synset_map):
    synset_groups = defaultdict(set)
    for lemma, syn in synset_map.items():
        if syn: # Check if syn is not None
            synset_groups[syn.name()].add(lemma)
        else:
            synset_groups[None].add(lemma)
    return synset_groups

def convert_docs_lemmas_to_synsets(documents_lemmas, synset_map):
    synset_documents = []
    for doc_lemmas in documents_lemmas:
        synset_doc = []
        for lemma in doc_lemmas:
            syn = synset_map.get(lemma)
            if syn: # Check if syn is not None
                synset_doc.append(syn.name())
        synset_documents.append(synset_doc)
    return synset_documents

def get_all_lemmas_from_doc_sentence_data(all_doc_sentence_data):
    all_docs_lemmas = []
    for doc_sentences in all_doc_sentence_data:
        doc_lemmas = []
        for entry in doc_sentences:
            doc_lemmas.extend(entry['lemmas'])
        all_docs_lemmas.append(doc_lemmas)
    return all_docs_lemmas

# ===== Main processing =====

# List your two PDF documents here
pdf_corpus_files = ['doc1.pdf', 'doc2.pdf', 'doc3.pdf', 'doc4.pdf', 'doc5.pdf', 'doc6.pdf', 'doc7.pdf', 'doc8.pdf', 'doc9.pdf',
 'doc10.pdf', 'doc11.pdf', 'doc12.pdf', 'doc13.pdf', 'doc14.pdf', 'doc15.pdf', 'doc16.pdf', 'doc17.pdf',
 'doc18.pdf', 'doc19.pdf', 'doc20.pdf', 'doc21.pdf', 'doc22.pdf', 'doc23.pdf', 'doc24.pdf']


print(f"Reading and processing {len(pdf_corpus_files)} PDF documents...")

all_doc_sentence_data = []
for pdf_file in pdf_corpus_files:
    text = read_pdf(pdf_file)
    sentence_data = preprocess_document(text)
    all_doc_sentence_data.append(sentence_data)

# Collect all lemmas from all documents
all_lemmas = set()
for doc_sentences in all_doc_sentence_data:
    for sent in doc_sentences:
        all_lemmas.update(sent['lemmas'])
print(f"Unique lemmas across the corpus: {len(all_lemmas)}")

# Assign synsets for all lemmas (aggregated from corpus)
# For better accuracy, ideally WSD should be per sentence + lemma,
# but here we assign one synset per lemma using the first context encountered
corpus_synset_map = {}
for doc_sentences in all_doc_sentence_data:
    synset_map = assign_synsets_to_lemmas(doc_sentences)
    corpus_synset_map.update(synset_map)
print(f"Lemmas with assigned synsets: {len(corpus_synset_map)}")


# Group lemmas by synset
lemma_groups_by_synset = group_lemmas_by_synset(corpus_synset_map)

print("\nSample synset groups (showing up to 5):")
for idx, (synset_name, lemmas) in enumerate(lemma_groups_by_synset.items()):
    if synset_name is not None:
        print(f"{synset_name}: {sorted(list(lemmas))}")
    if idx >= 4:
        break

# Print total number of unique synsets (excluding None)
num_real_synsets = sum(1 for syn in lemma_groups_by_synset if syn is not None)
print(f"\nNumber of unique synsets after grouping: {num_real_synsets}")


# Convert entire documents to synset-based representation
all_docs_lemmas = get_all_lemmas_from_doc_sentence_data(all_doc_sentence_data)
synset_docs = convert_docs_lemmas_to_synsets(all_docs_lemmas, corpus_synset_map)

# TF-IDF matrix creation
synset_docs_str = [' '.join(doc) for doc in synset_docs]

vectorizer = TfidfVectorizer(tokenizer=lambda x: x.split(), preprocessor=lambda x: x, lowercase=False)
tfidf_matrix = vectorizer.fit_transform(synset_docs_str)
feature_names = vectorizer.get_feature_names_out()

print(f"\nTF-IDF matrix (documents x synsets) shape = {tfidf_matrix.shape}")

# LDA topic modeling
num_topics = 4
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda.fit(tfidf_matrix)

topic_strengths = lda.components_.mean(axis=1)
top_topic_indices = topic_strengths.argsort()[::-1][:num_topics]

print(f"\nTop {num_topics} topic indices by average beta:")
print(top_topic_indices)

# Prepare data for coherence calculation
corpus_tokens = [doc.split() for doc in synset_docs_str]
dictionary = Dictionary(corpus_tokens)
gensim_corpus = [dictionary.doc2bow(text) for text in corpus_tokens]

print("\nTopic coherence scores:")

for topic_idx in top_topic_indices:
    top_indices = lda.components_[topic_idx].argsort()[-100:][::-1]
    top_synsets = [feature_names[i] for i in top_indices if i < len(feature_names)]

    cm = CoherenceModel(
        topics=[top_synsets],
        texts=corpus_tokens,
        dictionary=dictionary,
        coherence='c_v'
    )
    coherence_score = cm.get_coherence()
    print(f"Topic {topic_idx + 1} coherence score: {coherence_score:.4f}")

# Display top 10 synsets per topic
print("\nTop 10 synsets per topic:")
for topic_idx in range(num_topics):
    print(f"Topic {topic_idx + 1}:")
    top_indices = lda.components_[topic_idx].argsort()[-10:][::-1]
    top_synsets = [feature_names[i] for i in top_indices if i < len(feature_names)]
    print(", ".join(top_synsets))
    print()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# Reading and processing 24 PDF documents...
# Unique lemmas across the corpus: 13177
# Lemmas with assigned synsets: 13177
#
# Sample synset groups (showing up to 5):
# citizen.n.01: ['citizen']
# client.n.01: ['client']
# charter.n.01: ['charter']
# department.n.03: ['department']
# agricultural.a.01: ['agricultural']
#
# Number of unique synsets after grouping: 5888
#
# TF-IDF matrix (documents x synsets) shape = (24, 5888)
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Top 4 topic indices by average beta:
# [0 2 3 1]
#
# Topic coherence scores:
# Topic 1 coherence score: 0.3392
# Topic 3 coherence score: 0.4788
# Topic 4 coherence score: 0.8736
# Topic 2 coherence score: 0.6423
#
# Top 10 synsets per topic:
# Topic 1:
# research.v.02, agricultural.a.01, system.n.02, institute.v.02, education.n.05, university.n.03, total.v.03, grow.v.08, india.n.01, besides.r.02
#
# Topic 2:
# gravitational_constant.n.01, radius.n.01, barn.n.02, two.n.01, degree_centigrade.n.01, vitamin_e.n.01, farad.n.01, west.n.02, idaho.n.01, planck's_constant.n.01
#
# Topic 3:
# servicing.n.01, agricultural.a.01, research.v.02, director.n.03, sow.v.01, indentation.n.03, client.n.01, substantial.a.03, part.n.09, reception.n.04
#
# Topic 4:
# liter.n.01, cystic_fibrosis.n.01, farad.n.01, terrestrial_time.n.01, degree_centigrade.n.01, joule.n.01, radius.n.01, q.n.01, florida.n.01, computerized_tomography.n.01

# %%
#morphological Analysis
num_sentences = sum(len(doc_sentences) for doc_sentences in all_doc_sentence_data)

# Number of unique lemmas in the entire corpus
unique_lemmas = set()
for doc_sentences in all_doc_sentence_data:
    for sent in doc_sentences:
        unique_lemmas.update(sent['lemmas'])
num_lemmas = len(unique_lemmas)

# Number of unique synsets (excluding None)
num_synsets = sum(1 for syn in lemma_groups_by_synset if syn is not None)

print(f"Number of sentences: {num_sentences}")
print(f"Number of unique lemmas: {num_lemmas}")
print(f"Number of unique synsets: {num_synsets}")
# Out:
# Number of sentences: 12908
# Number of unique lemmas: 13177
# Number of unique synsets: 5888

# %%
#sysets formed for similar lemmas
for synset_name, lemmas in lemma_groups_by_synset.items():
    if synset_name is not None and len(lemmas) > 1:
        print(f"Synset: {synset_name} | Lemmas: {sorted(lemmas)}")
# Out:
# Synset: farming.n.01 | Lemmas: ['agriculture', 'husbandry']
# Synset: web_site.n.01 | Lemmas: ['site', 'website']
# Synset: hypertext_transfer_protocol.n.01 | Lemmas: ['http', 'https']
# Synset: offspring.n.01 | Lemmas: ['issue', 'progeny']
# Synset: imagination.n.01 | Lemmas: ['imagination', 'vision']
# Synset: first_step.n.01 | Lemmas: ['initiative', 'initiatives']
# Synset: transaction.n.01 | Lemmas: ['dealing', 'transaction']
# Synset: sow.v.01 | Lemmas: ['seed', 'seeded', 'sow', 'sowing', 'sown']
# Synset: snip.v.02 | Lemmas: ['crop', 'cropping', 'prune', 'pruning']
# Synset: cosmopolitan.s.03 | Lemmas: ['general', 'worldwide']
# Synset: allotment.n.02 | Lemmas: ['allocation', 'allotment']
# Synset: supply.v.01 | Lemmas: ['furnish', 'furnishes', 'provide', 'supplied']
# Synset: october.n.01 | Lemmas: ['oct', 'october']
# Synset: order.v.03 | Lemmas: ['prescribe', 'prescribes']
# Synset: tip.v.03 | Lemmas: ['fee', 'feed']
# Synset: responsibility.n.03 | Lemmas: ['responsibilities', 'responsibility']
# Synset: kernel.n.03 | Lemmas: ['centre', 'kernel']
# Synset: analyze.v.01 | Lemmas: ['analyse', 'analyze', 'examine']
# Synset: directing.s.01 | Lemmas: ['directing', 'directive']
# Synset: territory.n.03 | Lemmas: ['soil', 'territory']
# Synset: state.n.04 | Lemmas: ['commonwealth', 'land']
# Synset: plan.v.01 | Lemmas: ['plan', 'planning']
# Synset: richness.n.05 | Lemmas: ['fertility', 'prolificacy']
# Synset: scientist.n.01 | Lemmas: ['scientist', 'scientists']
# Synset: prerequisite.n.01 | Lemmas: ['prerequisite', 'requirement']
# Synset: note.v.01 | Lemmas: ['mention', 'mentioning']
# Synset: training.n.01 | Lemmas: ['training', 'trainings']
# Synset: staff.n.03 | Lemmas: ['faculties', 'faculty']
# Synset: receive.v.12 | Lemmas: ['receive', 'receiving']
# Synset: store.n.02 | Lemmas: ['fund', 'stock']
# Synset: india.n.01 | Lemmas: ['bharat', 'india']
# Synset: entrance.n.03 | Lemmas: ['entrance', 'incoming']
# Synset: guidance.n.01 | Lemmas: ['counsel', 'counselling']
# Synset: meet.v.09 | Lemmas: ['meet', 'meeting']
# Synset: disease.n.01 | Lemmas: ['disease', 'diseases']
# Synset: virus.n.03 | Lemmas: ['virus', 'viruses']
# Synset: milk.v.03 | Lemmas: ['milk', 'milking']
# Synset: semen.n.01 | Lemmas: ['cum', 'semen']
# Synset: screen.v.01 | Lemmas: ['screened', 'test']
# Synset: admit.v.03 | Lemmas: ['admit', 'admitted', 'include', 'included']
# Synset: emerge.v.04 | Lemmas: ['emerge', 'emerging']
# Synset: subject.n.06 | Lemmas: ['case', 'subject']
# Synset: prototype.n.01 | Lemmas: ['prototype', 'prototypes']
# Synset: thousand.s.01 | Lemmas: ['k', 'm']
# Synset: motivation.n.01 | Lemmas: ['motivation', 'need']
# Synset: inform.v.01 | Lemmas: ['inform', 'informs']
# Synset: sequestration.n.04 | Lemmas: ['requisition', 'sequestration']
# Synset: criterion.n.02 | Lemmas: ['criterion', 'standard']
# Synset: part.n.09 | Lemmas: ['division', 'part']
# Synset: month.n.02 | Lemmas: ['month', 'months']
# Synset: technology.n.01 | Lemmas: ['engineering', 'technologies', 'technology']
# Synset: well.r.01 | Lemmas: ['better', 'good']
# Synset: initiate.v.02 | Lemmas: ['initiate', 'pioneer']
# Synset: mechanism.n.04 | Lemmas: ['mechanism', 'mechanisms']
# Synset: fertilizer.n.01 | Lemmas: ['fertiliser', 'fertilizer']
# Synset: lab.n.01 | Lemmas: ['lab', 'laboratory', 'labs']
# Synset: deem.v.01 | Lemmas: ['deem', 'deemed']
# Synset: university.n.03 | Lemmas: ['universities', 'university']
# Synset: supplier.n.01 | Lemmas: ['provider', 'supplier', 'suppliers']
# Synset: veterinarian.n.01 | Lemmas: ['vet', 'veterinarian', 'veterinary']
# Synset: entrepreneur.n.01 | Lemmas: ['entrepreneur', 'entrepreneurs']
# Synset: subordinate.n.01 | Lemmas: ['subordinate', 'subsidiary']
# Synset: see.v.10 | Lemmas: ['check', 'checking', 'controlling', 'ensure', 'ensuring', 'insure']
# Synset: skill.n.01 | Lemmas: ['acquisition', 'skill']
# Synset: natural_process.n.01 | Lemmas: ['action', 'activity']
# Synset: meter.n.03 | Lemmas: ['measure', 'meter']
# Synset: fisherman.n.01 | Lemmas: ['fisher', 'fisherman']
# Synset: period.n.07 | Lemmas: ['period', 'stop']
# Synset: pack.v.13 | Lemmas: ['pack', 'packing']
# Synset: messenger.n.01 | Lemmas: ['courier', 'messenger']
# Synset: pool.v.02 | Lemmas: ['pool', 'pooled']
# Synset: newly.r.01 | Lemmas: ['fresh', 'freshly', 'newly']
# Synset: milliliter.n.01 | Lemmas: ['cc', 'mil', 'ml']
# Synset: hour.n.01 | Lemmas: ['hr', 'hrs']
# Synset: software.n.01 | Lemmas: ['package', 'software']
# Synset: download.v.01 | Lemmas: ['download', 'downloads']
# Synset: hold.v.10 | Lemmas: ['sustain', 'sustaining']
# Synset: vitamin_e.n.01 | Lemmas: ['e', 'es']
# Synset: zone.v.01 | Lemmas: ['district', 'zone']
# Synset: advisory.s.01 | Lemmas: ['advisory', 'consultative']
# Synset: january.n.01 | Lemmas: ['jan', 'january']
# Synset: two.n.01 | Lemmas: ['ii', 'iis', 'two']
# Synset: august.n.01 | Lemmas: ['aug', 'august']
# Synset: needed.s.01 | Lemmas: ['required', 'requisite']
# Synset: authentic.s.01 | Lemmas: ['authentic', 'reliable']
# Synset: improvement.n.01 | Lemmas: ['advance', 'betterment']
# Synset: four.n.01 | Lemmas: ['four', 'iv']
# Synset: erbium.n.01 | Lemmas: ['er', 'ers']
# Synset: triiodothyronine.n.01 | Lemmas: ['t', 'ts']
# Synset: degree_centigrade.n.01 | Lemmas: ['c', 'cs']
# Synset: gene.n.01 | Lemmas: ['factor', 'gene']
# Synset: iron.n.01 | Lemmas: ['fe', 'iron']
# Synset: approve.v.02 | Lemmas: ['approve', 'approved']
# Synset: technical.a.03 | Lemmas: ['technical', 'technological']
# Synset: espouse.v.03 | Lemmas: ['adopt', 'adopted', 'adopting']
# Synset: render.v.04 | Lemmas: ['generate', 'generated', 'generates']
# Synset: comprehensive_examination.n.01 | Lemmas: ['comp', 'comprehensive']
# Synset: objective.n.02 | Lemmas: ['objective', 'objectives']
# Synset: steering.n.02 | Lemmas: ['direction', 'guidance', 'steering']
# Synset: agency.n.01 | Lemmas: ['authority', 'bureau']
# Synset: function.n.03 | Lemmas: ['function', 'office', 'offices']
# Synset: oilseed.n.01 | Lemmas: ['oilseed', 'oilseeds']
# Synset: greenwich_village.n.01 | Lemmas: ['village', 'villages']
# Synset: about.r.07 | Lemmas: ['almost', 'near', 'virtually']
# Synset: crucial.a.01 | Lemmas: ['crucial', 'important']
# Synset: biotechnology.n.02 | Lemmas: ['biotechnology', 'ergonomics']
# Synset: soy.n.04 | Lemmas: ['soy', 'soya', 'soybean']
# Synset: worm.n.02 | Lemmas: ['insect', 'insects']
# Synset: potato.n.01 | Lemmas: ['potato', 'potatoes']
# Synset: weed.v.01 | Lemmas: ['weed', 'weeding']
# Synset: southeast.n.01 | Lemmas: ['se', 'southeast']
# Synset: railway.n.01 | Lemmas: ['railway', 'railways']
# Synset: reap.v.01 | Lemmas: ['harvest', 'harvesting', 'reap']
# Synset: library.n.05 | Lemmas: ['libraries', 'library']
# Synset: foreword.n.01 | Lemmas: ['foreword', 'preface']
# Synset: program.v.01 | Lemmas: ['programes', 'programme', 'programmed']
# Synset: commit.v.03 | Lemmas: ['commit', 'sends']
# Synset: transform.v.06 | Lemmas: ['transform', 'transforming']
# Synset: prove.v.02 | Lemmas: ['demonstrate', 'demonstrated', 'establish', 'prove']
# Synset: derive.v.05 | Lemmas: ['come', 'derive']
# Synset: effect.n.04 | Lemmas: ['burden', 'effect']
# Synset: component.n.03 | Lemmas: ['component', 'constituent']
# Synset: status.n.01 | Lemmas: ['position', 'status']
# Synset: power.v.01 | Lemmas: ['power', 'powered']
# Synset: department_of_energy.n.01 | Lemmas: ['doe', 'energy']
# Synset: handle.n.01 | Lemmas: ['handle', 'hold']
# Synset: former.s.03 | Lemmas: ['former', 'previous']
# Synset: organize.v.05 | Lemmas: ['organise', 'organises', 'organize', 'organizing']
# Synset: profit.v.01 | Lemmas: ['benefited', 'benefitted', 'benefitting']
# Synset: perform.v.03 | Lemmas: ['perform', 'performing', 'performs']
# Synset: stipulate.v.01 | Lemmas: ['qualify', 'specify']
# Synset: placement.n.01 | Lemmas: ['arrangement', 'placement']
# Synset: patent.v.02 | Lemmas: ['patent', 'patenting']
# Synset: name.v.03 | Lemmas: ['make', 'nominate']
# Synset: mandate.n.02 | Lemmas: ['mandate', 'mandatory']
# Synset: infrastructure.n.02 | Lemmas: ['base', 'infrastructure']
# Synset: consequence.n.01 | Lemmas: ['outcome', 'outcomes']
# Synset: better.v.02 | Lemmas: ['ameliorate', 'improve']
# Synset: teaching.n.01 | Lemmas: ['instruction', 'teaching']
# Synset: workshop.n.02 | Lemmas: ['workshop', 'workshops']
# Synset: seminar.n.02 | Lemmas: ['seminar', 'seminars']
# Synset: symposium.n.01 | Lemmas: ['symposia', 'symposium']
# Synset: grow.v.08 | Lemmas: ['acquire', 'acquired', 'develop', 'grown']
# Synset: besides.r.02 | Lemmas: ['also', 'besides']
# Synset: launch.v.03 | Lemmas: ['launch', 'launched']
# Synset: bless.v.03 | Lemmas: ['sign', 'signed', 'signing']
# Synset: facilitate.v.03 | Lemmas: ['facilitate', 'facilitates']
# Synset: like.a.01 | Lemmas: ['like', 'similar']
# Synset: trigger.n.03 | Lemmas: ['induction', 'trigger']
# Synset: promotion.n.03 | Lemmas: ['advancement', 'furtherance']
# Synset: recruit.v.03 | Lemmas: ['levy', 'recruit', 'recruited']
# Synset: undertake.v.03 | Lemmas: ['undertaken', 'undertook']
# Synset: survival.n.02 | Lemmas: ['selection', 'survival']
# Synset: retool.v.01 | Lemmas: ['revise', 'revised']
# Synset: late.s.03 | Lemmas: ['latest', 'recent']
# Synset: net_income.n.01 | Lemmas: ['earnings', 'net', 'profit']
# Synset: upload.v.01 | Lemmas: ['upload', 'uploaded', 'uploading']
# Synset: interview.v.03 | Lemmas: ['interview', 'interviewed']
# Synset: roast.n.01 | Lemmas: ['joint', 'roast']
# Synset: november.n.01 | Lemmas: ['nov', 'november']
# Synset: carry.v.29 | Lemmas: ['carry', 'carrying']
# Synset: enterprise.n.03 | Lemmas: ['enterprise', 'enterprises']
# Synset: integrate.v.01 | Lemmas: ['incorporate', 'integrate']
# Synset: promote.v.05 | Lemmas: ['promote', 'promoting']
# Synset: commercialization.n.01 | Lemmas: ['commercialisation', 'commercialization']
# Synset: standardize.v.01 | Lemmas: ['standardise', 'standardized']
# Synset: crore.n.01 | Lemmas: ['crore', 'crores']
# Synset: tax.n.01 | Lemmas: ['tax', 'taxation']
# Synset: lac.n.01 | Lemmas: ['lac', 'lacs']
# Synset: usher.v.01 | Lemmas: ['show', 'usher']
# Synset: dedicate.v.04 | Lemmas: ['dedicate', 'dedicated']
# Synset: organizational.a.01 | Lemmas: ['organisational', 'organizational']
# Synset: military_capability.n.01 | Lemmas: ['strength', 'strengths']
# Synset: organize.v.04 | Lemmas: ['coordinate', 'organizes']
# Synset: consist.v.04 | Lemmas: ['comprise', 'comprised', 'comprises', 'consist']
# Synset: steer.v.01 | Lemmas: ['directed', 'guide', 'point']
# Synset: manage.v.02 | Lemmas: ['manage', 'managing']
# Synset: impound.v.01 | Lemmas: ['attach', 'attached']
# Synset: accomplishment.n.01 | Lemmas: ['accomplishment', 'accomplishments', 'achievement', 'achievements']
# Synset: september.n.01 | Lemmas: ['sept', 'september']
# Synset: count.v.01 | Lemmas: ['count', 'enumerate']
# Synset: retain.v.02 | Lemmas: ['continue', 'continued', 'keeping', 'retain']
# Synset: become.v.04 | Lemmas: ['become', 'becomes']
# Synset: sustenance.n.03 | Lemmas: ['maintenance', 'sustenance', 'upkeep']
# Synset: satisfy.v.01 | Lemmas: ['fulfil', 'fulfill', 'satisfy']
# Synset: view.n.02 | Lemmas: ['aspect', 'prospect', 'vista']
# Synset: work_force.n.01 | Lemmas: ['manpower', 'workforce']
# Synset: quest_for.v.01 | Lemmas: ['pursue', 'pursuing']
# Synset: authorization.n.04 | Lemmas: ['authorization', 'empowerment']
# Synset: promise.v.04 | Lemmas: ['promise', 'promising']
# Synset: resilience.n.01 | Lemmas: ['resilience', 'resiliency']
# Synset: mechanization.n.01 | Lemmas: ['mechanisation', 'mechanization']
# Synset: practice.v.01 | Lemmas: ['do', 'dos', 'practice']
# Synset: thrive.v.02 | Lemmas: ['prosper', 'thrive', 'thriving']
# Synset: boundary.n.02 | Lemmas: ['bound', 'boundary']
# Synset: hundred_thousand.n.01 | Lemmas: ['lakh', 'lakhs']
# Synset: master.v.04 | Lemmas: ['controlled', 'master']
# Synset: program.n.05 | Lemmas: ['program', 'programmes']
# Synset: confer.v.01 | Lemmas: ['confer', 'consulting']
# Synset: restructure.v.01 | Lemmas: ['reconstitute', 'restructure']
# Synset: union.s.01 | Lemmas: ['federal', 'union']
# Synset: advise.v.02 | Lemmas: ['notified', 'notify']
# Synset: induce.v.02 | Lemmas: ['cause', 'stimulate', 'stimulating']
# Synset: worldly_concern.n.01 | Lemmas: ['earth', 'world']
# Synset: partnership.n.03 | Lemmas: ['partnership', 'partnerships']
# Synset: elaborate.v.01 | Lemmas: ['elaborate', 'expand', 'expanded']
# Synset: opportunity.n.01 | Lemmas: ['opportunities', 'opportunity']
# Synset: unite.v.05 | Lemmas: ['unify', 'unite', 'united']
# Synset: lend.v.01 | Lemmas: ['bring', 'contribute', 'impart']
# Synset: memo.n.01 | Lemmas: ['memoranda', 'memorandum']
# Synset: accelerate.v.02 | Lemmas: ['accelerate', 'accelerating']
# Synset: dry.v.01 | Lemmas: ['dried', 'dry', 'drying']
# Synset: gamble.v.01 | Lemmas: ['adventure', 'risk']
# Synset: participate.v.01 | Lemmas: ['participate', 'participated']
# Synset: united_states_army.n.01 | Lemmas: ['army', 'usa']
# Synset: achieve.v.01 | Lemmas: ['accomplish', 'accomplished', 'achieve', 'achieving']
# Synset: pronounce.v.01 | Lemmas: ['articulate', 'pronounce']
# Synset: trait.n.01 | Lemmas: ['trait', 'traits']
# Synset: sunday.n.01 | Lemmas: ['sun', 'sunday']
# Synset: similarly.r.01 | Lemmas: ['likewise', 'similarly']
# Synset: enzyme.n.01 | Lemmas: ['enzyme', 'enzymes']
# Synset: companion.n.01 | Lemmas: ['associate', 'fellow', 'fellows']
# Synset: twelve.n.01 | Lemmas: ['dozen', 'twelve']
# Synset: flower.n.03 | Lemmas: ['bloom', 'flower']
# Synset: bear.v.06 | Lemmas: ['accept', 'born']
# Synset: offer.n.01 | Lemmas: ['offer', 'offering']
# Synset: use.v.01 | Lemmas: ['utilize', 'utilized']
# Synset: apparent.s.01 | Lemmas: ['apparent', 'plain']
# Synset: embryo.n.02 | Lemmas: ['embryo', 'embryos']
# Synset: unwrap.v.02 | Lemmas: ['disclose', 'discover', 'expose', 'reveal', 'revealed']
# Synset: induce.v.05 | Lemmas: ['induce', 'induced']
# Synset: stripe.n.05 | Lemmas: ['bar', 'streak']
# Synset: medulla_oblongata.n.01 | Lemmas: ['bulb', 'bulbs']
# Synset: interact.v.01 | Lemmas: ['interact', 'interacted']
# Synset: fungus.n.01 | Lemmas: ['fungi', 'fungus']
# Synset: designate.v.01 | Lemmas: ['designate', 'designated']
# Synset: specimen.n.02 | Lemmas: ['specimen', 'specimens']
# Synset: vegetable.n.01 | Lemmas: ['veg', 'vegetables']
# Synset: educate.v.03 | Lemmas: ['cultivate', 'cultivating']
# Synset: down_payment.n.01 | Lemmas: ['deposit', 'deposits']
# Synset: initiation.n.02 | Lemmas: ['creation', 'foundation', 'initiation']
# Synset: detect.v.01 | Lemmas: ['detect', 'observe']
# Synset: control.v.02 | Lemmas: ['contain', 'contained']
# Synset: megabyte.n.02 | Lemmas: ['mb', 'mib']
# Synset: protein.n.01 | Lemmas: ['protein', 'proteins']
# Synset: decode.v.01 | Lemmas: ['decipher', 'decode']
# Synset: wholly.r.01 | Lemmas: ['altogether', 'completely', 'entirely', 'totally', 'whole', 'wholly']
# Synset: pod.n.01 | Lemmas: ['cod', 'pod']
# Synset: legume.n.02 | Lemmas: ['legume', 'legumes']
# Synset: volume.n.06 | Lemmas: ['intensity', 'volumes']
# Synset: beekeeping.n.01 | Lemmas: ['apiculture', 'beekeeping']
# Synset: trust.n.04 | Lemmas: ['combine', 'trust']
# Synset: experiment.n.02 | Lemmas: ['experiment', 'experimentation']
# Synset: pathogen.n.01 | Lemmas: ['pathogen', 'pathogens']
# Synset: show.v.01 | Lemmas: ['exhibit', 'presented', 'showing']
# Synset: proportion.n.04 | Lemmas: ['proportion', 'ratio']
# Synset: compare.v.04 | Lemmas: ['compare', 'compared']
# Synset: adviser.n.01 | Lemmas: ['adviser', 'advisor', 'consultant']
# Synset: readiness.n.01 | Lemmas: ['preparation', 'preparedness', 'readiness']
# Synset: algorithm.n.01 | Lemmas: ['algorithm', 'algorithms']
# Synset: testis.n.01 | Lemmas: ['ball', 'eggs', 'nut']
# Synset: due.n.02 | Lemmas: ['due', 'dues']
# Synset: graft.n.01 | Lemmas: ['graft', 'transplant']
# Synset: fully.r.01 | Lemmas: ['full', 'fully']
# Synset: isolate.v.04 | Lemmas: ['isolate', 'isolated', 'isolates']
# Synset: lepidopterous_insect.n.01 | Lemmas: ['lepidoptera', 'lepidopteran']
# Synset: measure.v.04 | Lemmas: ['evaluate', 'evaluated']
# Synset: sulphur.v.01 | Lemmas: ['sulfur', 'sulphur']
# Synset: inoculation.n.01 | Lemmas: ['inoculation', 'vaccination']
# Synset: tax.v.02 | Lemmas: ['assess', 'assessing']
# Synset: rapid.s.02 | Lemmas: ['rapid', 'speedy']
# Synset: validate.v.04 | Lemmas: ['validate', 'validated']
# Synset: sperm.n.01 | Lemmas: ['sperm', 'spermatozoon']
# Synset: world_wide_web.n.01 | Lemmas: ['web', 'www']
# Synset: lend_oneself.v.01 | Lemmas: ['apply', 'applying']
# Synset: categorize.v.01 | Lemmas: ['categorize', 'categorized']
# Synset: metric_ton.n.01 | Lemmas: ['tonne', 'tonnes']
# Synset: measurement.n.01 | Lemmas: ['measurement', 'measuring']
# Synset: adjust.v.03 | Lemmas: ['adapt', 'adapting', 'conform']
# Synset: adhesiveness.n.01 | Lemmas: ['adherence', 'adhesion']
# Synset: lack.n.01 | Lemmas: ['deficiency', 'lack', 'want']
# Synset: navigate.v.02 | Lemmas: ['navigate', 'pilot']
# Synset: human_body.n.01 | Lemmas: ['anatomy', 'bod']
# Synset: incubator.n.01 | Lemmas: ['brooder', 'incubator']
# Synset: enhance.v.02 | Lemmas: ['enhances', 'enhancing']
# Synset: restriction.n.01 | Lemmas: ['limitation', 'restriction']
# Synset: prepare.v.07 | Lemmas: ['prepare', 'prepared']
# Synset: define.v.02 | Lemmas: ['define', 'defined']
# Synset: millimeter.n.01 | Lemmas: ['millimeter', 'mm']
# Synset: closely.r.03 | Lemmas: ['closely', 'nearly']
# Synset: intercede.v.01 | Lemmas: ['intermediate', 'liaise', 'mediate']
# Synset: pulley.n.01 | Lemmas: ['block', 'pulley']
# Synset: therefore.r.01 | Lemmas: ['hence', 'therefore']
# Synset: river_basin.n.01 | Lemmas: ['basins', 'watershed']
# Synset: minimize.v.03 | Lemmas: ['minimize', 'minimizing']
# Synset: smell.v.05 | Lemmas: ['sense', 'sensing']
# Synset: pond.n.01 | Lemmas: ['pond', 'ponds']
# Synset: coarse.s.03 | Lemmas: ['coarse', 'coarser']
# Synset: ascend.v.08 | Lemmas: ['rise', 'risen']
# Synset: save.v.09 | Lemmas: ['economizes', 'save']
# Synset: modify.v.02 | Lemmas: ['modified', 'modify', 'modifying']
# Synset: reform.v.02 | Lemmas: ['reclaim', 'rectify']
# Synset: drive.v.20 | Lemmas: ['drive', 'driven']
# Synset: distribute.v.01 | Lemmas: ['allot', 'dispense']
# Synset: fertilize.v.01 | Lemmas: ['feeding', 'fertilize']
# Synset: actual.s.03 | Lemmas: ['actual', 'genuine']
# Synset: coincident.s.01 | Lemmas: ['concurrent', 'simultaneous']
# Synset: majority.n.01 | Lemmas: ['bulk', 'majority']
# Synset: zymosis.n.01 | Lemmas: ['ferment', 'fermentation']
# Synset: consider.v.09 | Lemmas: ['consider', 'considers']
# Synset: color.n.08 | Lemmas: ['color', 'colour']
# Synset: buttocks.n.01 | Lemmas: ['behind', 'bottom']
# Synset: consortium.n.01 | Lemmas: ['consortia', 'consortium']
# Synset: germination.n.01 | Lemmas: ['germination', 'sprouting']
# Synset: analyzer.n.01 | Lemmas: ['analyser', 'analyzer']
# Synset: utah.n.01 | Lemmas: ['ut', 'utah', 'uts']
# Synset: astronomical_unit.n.01 | Lemmas: ['au', 'aus']
# Synset: promote.v.01 | Lemmas: ['advancing', 'boost', 'encourage', 'encouraging', 'promotes']
# Synset: tone.v.05 | Lemmas: ['strengthen', 'strengthening']
# Synset: digitize.v.01 | Lemmas: ['digitize', 'digitized']
# Synset: proceeding.n.01 | Lemmas: ['proceeding', 'proceedings']
# Synset: ecosystem.n.01 | Lemmas: ['ecosystem', 'ecosystems']
# Synset: hertz.n.01 | Lemmas: ['cps', 'cycle', 'hz']
# Synset: update.v.03 | Lemmas: ['update', 'updated']
# Synset: rent.v.04 | Lemmas: ['hire', 'hiring', 'leasing', 'rent']
# Synset: x.n.02 | Lemmas: ['ex', 'x']
# Synset: edit.v.03 | Lemmas: ['edit', 'edited', 'editing']
# Synset: zinc.n.01 | Lemmas: ['zinc', 'zn']
# Synset: option.n.02 | Lemmas: ['alternative', 'choice']
# Synset: world.n.02 | Lemmas: ['domain', 'domains']
# Synset: nothing.n.01 | Lemmas: ['nil', 'null']
# Synset: widen.v.04 | Lemmas: ['broaden', 'widen']
# Synset: parental.a.02 | Lemmas: ['maternal', 'parental']
# Synset: chaff.n.01 | Lemmas: ['stalk', 'straw']
# Synset: version.n.02 | Lemmas: ['variant', 'variation', 'version']
# Synset: imagine.v.01 | Lemmas: ['envisage', 'envisages', 'imagine']
# Synset: chromium.n.01 | Lemmas: ['chromium', 'cr']
# Synset: sleeve.n.01 | Lemmas: ['arm', 'sleeve']
# Synset: superintendent.n.02 | Lemmas: ['super', 'superintendent']
# Synset: optimum.s.01 | Lemmas: ['optimal', 'optimum']
# Synset: trail.v.05 | Lemmas: ['trail', 'trails']
# Synset: refer.v.02 | Lemmas: ['pertain', 'pertains']
# Synset: youth.n.06 | Lemmas: ['youth', 'youths']
# Synset: sponsor.v.02 | Lemmas: ['sponsor', 'sponsored']
# Synset: attract.v.03 | Lemmas: ['attract', 'attracting']
# Synset: photograph.n.01 | Lemmas: ['exposure', 'photograph', 'pic']
# Synset: movie.n.01 | Lemmas: ['film', 'picture']
# Synset: recently.r.01 | Lemmas: ['late', 'recently']
# Synset: wide.a.01 | Lemmas: ['broader', 'wider']
# Synset: certify.v.02 | Lemmas: ['certified', 'certify']
# Synset: label.v.05 | Lemmas: ['labeled', 'labelled']
# Synset: compost.v.01 | Lemmas: ['compost', 'composting']
# Synset: realize.v.06 | Lemmas: ['realize', 'realizing']
# Synset: involve.v.06 | Lemmas: ['involve', 'involved', 'involving']
# Synset: proficiency.n.02 | Lemmas: ['proficiency', 'technique']
# Synset: information_science.n.01 | Lemmas: ['informatics', 'ip']
# Synset: report.v.01 | Lemmas: ['account', 'describe']
# Synset: assure.v.03 | Lemmas: ['assure', 'assured']
# Synset: roll.v.14 | Lemmas: ['revolve', 'revolving', 'roll']
# Synset: talk.v.02 | Lemmas: ['speak', 'speaking']
# Synset: publish.v.02 | Lemmas: ['issued', 'publish']
# Synset: report.v.05 | Lemmas: ['reported', 'reporting']
# Synset: very_important_person.n.01 | Lemmas: ['dignitary', 'vip']
# Synset: draft.n.07 | Lemmas: ['draft', 'drafts']
# Synset: audit.v.01 | Lemmas: ['audited', 'inspect']
# Synset: undergo.v.01 | Lemmas: ['undergo', 'undergoing', 'undergone']
# Synset: organized.s.03 | Lemmas: ['organised', 'organized']
# Synset: rotter.n.01 | Lemmas: ['git', 'rat']
# Synset: car.n.01 | Lemmas: ['auto', 'automobile']
# Synset: sexual_intercourse.n.01 | Lemmas: ['congress', 'relation']
# Synset: fact.n.03 | Lemmas: ['fact', 'facts']
# Synset: qi.n.01 | Lemmas: ['chi', 'ki']
# Synset: emirate.n.02 | Lemmas: ['emirate', 'emirates']
# Synset: united_nations.n.01 | Lemmas: ['un', 'uns']
# Synset: five_hundred.s.01 | Lemmas: ['d', 'der']
# Synset: computerized_tomography.n.01 | Lemmas: ['cat', 'ct']
# Synset: invent.v.01 | Lemmas: ['formulate', 'formulating']
# Synset: fund.v.05 | Lemmas: ['funded', 'funding']
# Synset: sanction.v.03 | Lemmas: ['sanction', 'sanctioned']
# Synset: attention.n.01 | Lemmas: ['attending', 'attention']
# Synset: drink.n.02 | Lemmas: ['drink', 'drinking']
# Synset: tear.v.03 | Lemmas: ['charged', 'shoot']
# Synset: tropical.s.04 | Lemmas: ['tropic', 'tropical']
# Synset: taiwan.n.01 | Lemmas: ['china', 'taiwan']
# Synset: myanmar.n.01 | Lemmas: ['burma', 'myanmar']
# Synset: startup.n.01 | Lemmas: ['startup', 'startups']
# Synset: incubate.v.01 | Lemmas: ['incubate', 'incubated', 'incubatees']
# Synset: appoint.v.02 | Lemmas: ['appoint', 'appointing']
# Synset: think_of.v.03 | Lemmas: ['esteem', 'reputed']
# Synset: eight.n.01 | Lemmas: ['eight', 'viii']
# Synset: seller.n.01 | Lemmas: ['seller', 'vendor']
# Synset: intensify.v.02 | Lemmas: ['compound', 'deepen']
# Synset: president.n.04 | Lemmas: ['chairman', 'chairperson']
# Synset: recourse.n.01 | Lemmas: ['recourses', 'resort']
# Synset: debate.v.03 | Lemmas: ['debate', 'deliberate']
# Synset: course_of_study.n.01 | Lemmas: ['curriculum', 'syllabus']
# Synset: install.v.01 | Lemmas: ['instal', 'install']
# Synset: hostel.n.02 | Lemmas: ['hostel', 'hostels']
# Synset: inaugurate.v.03 | Lemmas: ['inaugurate', 'inaugurated']
# Synset: deputation.n.01 | Lemmas: ['delegation', 'deputation']
# Synset: alimentary.s.01 | Lemmas: ['nutritious', 'nutritive']
# Synset: girlfriend.n.02 | Lemmas: ['girl', 'girls']
# Synset: professor.n.01 | Lemmas: ['prof', 'professor']
# Synset: michigan.n.03 | Lemmas: ['chicago', 'michigan']
# Synset: sanchez.n.01 | Lemmas: ['carlos', 'salim']
# Synset: doorsill.n.01 | Lemmas: ['doorsteps', 'threshold']
# Synset: spectrum.n.02 | Lemmas: ['spectra', 'spectrum']
# Synset: stipulate.v.03 | Lemmas: ['stipulate', 'stipulated']
# Synset: conducive.s.01 | Lemmas: ['conducive', 'contributory']
# Synset: idea.n.01 | Lemmas: ['idea', 'ideas']
# Synset: think.v.03 | Lemmas: ['think', 'thinking', 'thought']
# Synset: stay.v.01 | Lemmas: ['remain', 'stay']
# Synset: competence.n.01 | Lemmas: ['competence', 'competency']
# Synset: maximize.v.02 | Lemmas: ['maximize', 'maximized', 'maximizing']
# Synset: larva.n.01 | Lemmas: ['larva', 'larvae']
# Synset: introduce.v.07 | Lemmas: ['introduce', 'introducing']
# Synset: tract.n.03 | Lemmas: ['pamphlet', 'tract']
# Synset: underscore.v.01 | Lemmas: ['emphasise', 'emphasize', 'underline', 'underscore']
# Synset: honor.n.03 | Lemmas: ['honor', 'honour']
# Synset: peak.n.04 | Lemmas: ['peak', 'summit']
# Synset: manufacture.v.01 | Lemmas: ['construct', 'fabricate', 'manufacturing']
# Synset: manor_hall.n.01 | Lemmas: ['hall', 'halls']
# Synset: boy.n.04 | Lemmas: ['boy', 'boys']
# Synset: shop.n.01 | Lemmas: ['shop', 'store']
# Synset: spectroscopy.n.01 | Lemmas: ['spectrometry', 'spectroscopy']
# Synset: learn.v.04 | Lemmas: ['learning', 'learnt']
# Synset: embark.v.02 | Lemmas: ['embark', 'enters']
# Synset: always.r.01 | Lemmas: ['always', 'ever']
# Synset: noteworthy.s.02 | Lemmas: ['noteworthy', 'remarkable']
# Synset: signify.v.03 | Lemmas: ['signifies', 'signify']
# Synset: qualify.v.06 | Lemmas: ['characterize', 'characterized', 'qualifying']
# Synset: surpass.v.02 | Lemmas: ['exceed', 'outgo', 'surpass']
# Synset: township.n.01 | Lemmas: ['town', 'township']
# Synset: catalyze.v.01 | Lemmas: ['catalyse', 'catalyze']
# Synset: firm.s.10 | Lemmas: ['fast', 'firm']
# Synset: collaborate.v.01 | Lemmas: ['collaborate', 'collaborated']
# Synset: huge.s.01 | Lemmas: ['huge', 'immense']
# Synset: prohibition.n.05 | Lemmas: ['inhibition', 'prohibition']
# Synset: spirit.n.02 | Lemmas: ['flavor', 'flavour', 'look', 'spirit']
# Synset: match.v.01 | Lemmas: ['agree', 'agrees']
# Synset: simulate.v.03 | Lemmas: ['assume', 'simulate']
# Synset: optimization.n.01 | Lemmas: ['optimisation', 'optimization']
# Synset: exalted.s.01 | Lemmas: ['elevated', 'grand']
# Synset: license.n.04 | Lemmas: ['permission', 'permit']
# Synset: determine.v.08 | Lemmas: ['ascertained', 'learn']
# Synset: fairly.r.03 | Lemmas: ['clean', 'fair']
# Synset: iowa.n.02 | Lemmas: ['ia', 'iowa']
# Synset: clarify.v.01 | Lemmas: ['clarify', 'elucidate']
# Synset: kolkata.n.01 | Lemmas: ['calcutta', 'kolkata']
# Synset: godhead.n.01 | Lemmas: ['creator', 'maker']
# Synset: educationist.n.01 | Lemmas: ['educationist', 'educationists']
# Synset: scaling.n.01 | Lemmas: ['grading', 'scaling']
# Synset: happen.v.02 | Lemmas: ['happen', 'happening']
# Synset: soon.r.01 | Lemmas: ['presently', 'shortly', 'soon']
# Synset: forty.s.01 | Lemmas: ['forty', 'xl']
# Synset: align.v.03 | Lemmas: ['align', 'aligning']
# Synset: use.n.01 | Lemmas: ['employment', 'utilisation']
# Synset: attendant.n.02 | Lemmas: ['attendee', 'attendees']
# Synset: conjunction.n.05 | Lemmas: ['alignment', 'conjunction']
# Synset: announce.v.03 | Lemmas: ['announce', 'announces']
# Synset: reschedule.v.01 | Lemmas: ['reschedule', 'rescheduling']
# Synset: empower.v.01 | Lemmas: ['authorize', 'authorized']
# Synset: impart.v.03 | Lemmas: ['convey', 'conveyed', 'transmits']
# Synset: engineer.n.01 | Lemmas: ['technologist', 'technologists']
# Synset: extenuate.v.01 | Lemmas: ['mitigate', 'mitigating']
# Synset: department_of_defense.n.01 | Lemmas: ['defense', 'dod']
# Synset: unravel.v.01 | Lemmas: ['unravel', 'unravelling']
# Synset: enroll.v.01 | Lemmas: ['enrol', 'enroll']
# Synset: rendition.n.04 | Lemmas: ['interpretation', 'rendition']
# Synset: liter.n.01 | Lemmas: ['l', 'litre']
# Synset: fatty.a.01 | Lemmas: ['fat', 'fatty']
# Synset: process.v.01 | Lemmas: ['processed', 'treat']
# Synset: determination.n.02 | Lemmas: ['determination', 'purpose']
# Synset: world.n.08 | Lemmas: ['humanity', 'man']
# Synset: disburse.v.01 | Lemmas: ['disburse', 'disbursing']
# Synset: oversee.v.01 | Lemmas: ['oversee', 'supervise']
# Synset: routine.n.03 | Lemmas: ['procedure', 'routine']
# Synset: thirteen.n.01 | Lemmas: ['thirteen', 'xiii']
# Synset: headroom.n.01 | Lemmas: ['clearance', 'headway']
# Synset: fourteen.s.01 | Lemmas: ['fourteen', 'xiv']
# Synset: supervision.n.01 | Lemmas: ['oversight', 'superintendence', 'supervision']
# Synset: try.v.08 | Lemmas: ['render', 'rendered', 'rendering']
# Synset: normally.r.01 | Lemmas: ['commonly', 'normally', 'ordinarily', 'usually']
# Synset: favor.n.02 | Lemmas: ['favor', 'favour']
# Synset: once.r.03 | Lemmas: ['erstwhile', 'formerly']
# Synset: still.v.03 | Lemmas: ['ease', 'relieve']
# Synset: furthermore.r.01 | Lemmas: ['furthermore', 'moreover']
# Synset: signature.n.05 | Lemmas: ['signature', 'signatures']
# Synset: compulsorily.r.01 | Lemmas: ['compulsorily', 'mandatorily']
# Synset: release.v.09 | Lemmas: ['released', 'releasing']
# Synset: spending.n.01 | Lemmas: ['disbursement', 'outlay']
# Synset: verify.v.01 | Lemmas: ['verified', 'verify']
# Synset: wage.n.01 | Lemmas: ['salary', 'wage']
# Synset: avail.v.02 | Lemmas: ['avail', 'availing']
# Synset: texas.n.01 | Lemmas: ['texas', 'tx']
# Synset: department_of_commerce.n.01 | Lemmas: ['commerce', 'doc']
# Synset: travel.v.06 | Lemmas: ['travel', 'traveling', 'travelling']
# Synset: alternatively.r.01 | Lemmas: ['alternatively', 'instead']
# Synset: organizer.n.01 | Lemmas: ['organiser', 'organizer', 'organizers']
# Synset: tuberculosis.n.01 | Lemmas: ['tb', 'tuberculosis']
# Synset: microbe.n.01 | Lemmas: ['germ', 'microbe']
# Synset: standardization.n.02 | Lemmas: ['normalization', 'standardization']
# Synset: louisiana.n.01 | Lemmas: ['la', 'louisiana']
# Synset: vegetation.n.01 | Lemmas: ['botany', 'flora']
# Synset: debar.v.02 | Lemmas: ['avoids', 'debarred']
# Synset: aforesaid.s.01 | Lemmas: ['aforementioned', 'aforesaid']
# Synset: agriculturist.n.01 | Lemmas: ['grower', 'raiser']
# Synset: mendelevium.n.01 | Lemmas: ['md', 'mv']
# Synset: headquarter.v.01 | Lemmas: ['headquarter', 'headquartered']
# Synset: sodium.n.01 | Lemmas: ['na', 'sodium']
# Synset: gulp.n.01 | Lemmas: ['draught', 'swig']
# Synset: vary.v.04 | Lemmas: ['varied', 'varies']
# Synset: mohammed.n.01 | Lemmas: ['mohammad', 'mohammed']
# Synset: fudge.v.01 | Lemmas: ['cook', 'cooking']
# Synset: traffic_circle.n.01 | Lemmas: ['circle', 'rotary']
# Synset: shining_path.n.01 | Lemmas: ['sl', 'sls']
# Synset: frequently.r.01 | Lemmas: ['frequently', 'oft']
# Synset: outbreak.n.01 | Lemmas: ['outbreak', 'outbreaks']
# Synset: popularize.v.01 | Lemmas: ['popularise', 'popularize']
# Synset: hands.n.01 | Lemmas: ['custody', 'hands']
# Synset: reclamation.n.01 | Lemmas: ['reclamation', 'renewal']
# Synset: messenger_rna.n.01 | Lemmas: ['mrna', 'mrnas']
# Synset: metabolite.n.01 | Lemmas: ['metabolite', 'metabolites']
# Synset: insufficient.a.01 | Lemmas: ['deficient', 'insufficient']
# Synset: desire.v.03 | Lemmas: ['desire', 'desired']
# Synset: florida.n.01 | Lemmas: ['fl', 'florida']
# Synset: shot.n.09 | Lemmas: ['barb', 'dig']
# Synset: sell.v.02 | Lemmas: ['sell', 'selling']
# Synset: weevil.n.01 | Lemmas: ['weevil', 'weevils']
# Synset: canine.n.01 | Lemmas: ['canine', 'canines']
# Synset: demobilize.v.01 | Lemmas: ['inactivate', 'inactivated']
# Synset: dependence.n.01 | Lemmas: ['dependence', 'dependency']
# Synset: portrayal.n.02 | Lemmas: ['characterization', 'enactment']
# Synset: encapsulate.v.02 | Lemmas: ['encapsulate', 'encapsulated']
# Synset: hazelnut.n.02 | Lemmas: ['cob', 'cobs']
# Synset: grove.n.02 | Lemmas: ['grove', 'orchard']
# Synset: total.v.02 | Lemmas: ['added', 'tally', 'tot']
# Synset: superannuate.v.01 | Lemmas: ['superannuate', 'superannuated']
# Synset: automatize.v.02 | Lemmas: ['automate', 'automated']
# Synset: regulate.v.01 | Lemmas: ['regulate', 'regulated']
# Synset: treaty.n.01 | Lemmas: ['pacts', 'treaty']
# Synset: golden.s.06 | Lemmas: ['favourable', 'prosperous']
# Synset: digest.v.03 | Lemmas: ['abide', 'brook']
# Synset: recur.v.02 | Lemmas: ['recur', 'recurring']
# Synset: pursuit.n.01 | Lemmas: ['following', 'pursuit']
# Synset: pander.v.02 | Lemmas: ['procured', 'procuring']
# Synset: universalize.v.01 | Lemmas: ['universalise', 'universalize']
# Synset: configure.v.01 | Lemmas: ['configure', 'configuring']
# Synset: print.v.04 | Lemmas: ['impressed', 'printed']
# Synset: installation.n.01 | Lemmas: ['installation', 'installment']
# Synset: breakwater.n.01 | Lemmas: ['jetty', 'mole']
# Synset: toilet.n.02 | Lemmas: ['can', 'pot']
# Synset: width.n.01 | Lemmas: ['breadth', 'width']
# Synset: digitization.n.01 | Lemmas: ['digitisation', 'digitization']
# Synset: transportation.n.02 | Lemmas: ['conveyance', 'transport']
# Synset: wetland.n.01 | Lemmas: ['wetland', 'wetlands']
# Synset: carbohydrate.n.01 | Lemmas: ['carbohydrate', 'sugar']
# Synset: trace.v.02 | Lemmas: ['delineate', 'described']
# Synset: possess.v.03 | Lemmas: ['possess', 'possesses']
# Synset: hormone.n.01 | Lemmas: ['hormone', 'hormones']
# Synset: crossbreed.v.01 | Lemmas: ['crossbred', 'crossbreed']
# Synset: supplementary.s.02 | Lemmas: ['supplemental', 'supplementary']
# Synset: prevent.v.02 | Lemmas: ['prevent', 'prevents']
# Synset: oxygen.n.01 | Lemmas: ['o', 'oxygen']
# Synset: journalist.n.01 | Lemmas: ['journalist', 'journalists']
# Synset: methamphetamine.n.01 | Lemmas: ['ice', 'trash']
# Synset: ask.v.05 | Lemmas: ['ask', 'asked']
# Synset: estimate.v.01 | Lemmas: ['approximate', 'estimated']
# Synset: locust_tree.n.01 | Lemmas: ['locust', 'locusts']
# Synset: ea.n.01 | Lemmas: ['ea', 'eas']
# Synset: fulfillment.n.02 | Lemmas: ['fulfillment', 'fulfilment']
# Synset: ti.n.03 | Lemmas: ['si', 'te']
# Synset: undersign.v.01 | Lemmas: ['undersign', 'undersigned']
# Synset: hereby.r.01 | Lemmas: ['hereby', 'herewith']
# Synset: deploy.v.02 | Lemmas: ['deploy', 'deployed']
